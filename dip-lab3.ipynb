# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from skimage.io import imread,imshow
# img1=imread('../input/dip-lab-images-3/Screenshot (33).png')
# img1=imread(r"D:\sem 5\digital image processing\assignment 3\spider-man-no-way-home-the-fun-stuff-version-poster.webp")
# img2=imread('../input/dip-lab-images-3/Screenshot (36).png')
img2=imread(r"C:\Users\bodla\OneDrive - Mahindra University\Pictures\Screenshots\Screenshot (36).png")
img1=imread(r"D:\sem 5\digital image processing\assignment 3\_122511907_72a2eab6-93a2-4801-8d6f-cf7fbc4d0fbe.jpg")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1.shape
# Out:
# (360, 640, 3)

# %%
imshow(img1)

# %%
from skimage.transform import resize
img2=resize(img2,(360,640,3))
imshow(img2)

# %%
img2.shape
# Out:
# (360, 640, 3)

# %%
#with numpy 
import cv2 
plt.figsize=(16,16)
plt.hist(img1.ravel(),256,[0,256])
plt.show()

# %%
#with opencv
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img1],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
mask = np.zeros(img1.shape[:2], np.uint8)
mask[100:300, 100:400] = 255
masked_img = cv2.bitwise_and(img1,img1,mask = mask)

# Calculate histogram with mask and without mask
# Check third argument for mask
hist_full = cv2.calcHist([img1],[0],None,[256],[0,256])
hist_mask = cv2.calcHist([img1],[0],mask,[256],[0,256])

plt.subplot(221), plt.imshow(img1, 'gray')
plt.subplot(222), plt.imshow(mask,'gray')
plt.subplot(223), plt.imshow(masked_img, 'gray')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.xlim([0,256])

plt.show()

# %%
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
equalized = cv2.equalizeHist(gray)

# %%
equalized.shape
# Out:
# (360, 640)

# %%
hist_full1 = cv2.calcHist([equalized],[0],None,[256],[0,256])
plt.imshow(hist_full1)

# %%
plt.figsize=(16,16)
plt.hist(equalized.ravel(),256,[0,256])
plt.show()

# %%
img_add=cv2.add(img1,img2,dtype=cv2.CV_64F)
imshow(img_add)
# Out:
# c:\Users\bodla\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_add_np=img1+img2
imshow(img_add_np)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_sub=cv2.subtract(img1,img2,dtype=cv2.CV_64F)
# lo, hi, cmap = _get_display_range(img_sub)
imshow(img_sub)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_sub_np=img1-img2
imshow(img_sub_np)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_mult=cv2.multiply(img1,img2,dtype=cv2.CV_64F)
imshow(img_mult)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_mult_np=img1*img2
imshow(img_mult_np)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_np_div=img1/img2
imshow(img_np_div)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

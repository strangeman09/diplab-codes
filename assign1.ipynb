# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
image_dir=r"C:\Users\bodla\OneDrive - Mahindra University\Pictures\Camera Roll\WIN_20220902_22_02_52_Pro.jpg"
from skimage.io import imread,imshow
image_ski=imread(image_dir,as_gray=False)
imshow(image_ski)

# %%
image_ski.shape
# Out:
# (720, 1280, 3)

# %%
from skimage.transform import resize,rescale
image_ski=resize(image_ski,(256,256))
imshow(image_ski)

# %%
# image_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
# plt.imshow(image_gray)

# %%
image_gray_ski=imread(image_dir,as_gray=True)
imshow(image_gray_ski)

# %%
r,g,b=image_ski[:,:,0],image_ski[:,:,1],image_ski[:,:,2]
r_img=r+0*g+0*b
imshow(r_img)

# %%
g_img=0*r+g+0*b
imshow(g_img)

# %%
b_img=0*r+0*g+b
imshow(b_img)

# %%
#looping and control flow
count=0
for i in range(0,100):
    count+=1

if count> 100 :
    print("hello")
else:
    print('bye')
# Out:
# bye

# %%
from PIL import Image as im
arr=np.arange(0,65536,1,np.uint8)
arr=np.reshape(arr,(256,256))

# %%
data = im.fromarray(arr)
data.save('waste.png')

# %%
list1=[]
x=116640
count=0
while(count<518400):
    if(x%2==0):
        x=x/2
    else:
        x=3*x+1
    list1.append(x)
    count+=1

# %%
len(list1)
# Out:
# 518400

# %%
arr=np.array(list1)
# arr=arr/len(list1)

# %%
arr=np.reshape(arr,(720,720))

# %%
arr
# Out:
# array([[5.832e+04, 2.916e+04, 1.458e+04, ..., 4.000e+00, 2.000e+00,
#         1.000e+00],
#        [4.000e+00, 2.000e+00, 1.000e+00, ..., 4.000e+00, 2.000e+00,
#         1.000e+00],
#        [4.000e+00, 2.000e+00, 1.000e+00, ..., 4.000e+00, 2.000e+00,
#         1.000e+00],
#        ...,
#        [4.000e+00, 2.000e+00, 1.000e+00, ..., 4.000e+00, 2.000e+00,
#         1.000e+00],
#        [4.000e+00, 2.000e+00, 1.000e+00, ..., 4.000e+00, 2.000e+00,
#         1.000e+00],
#        [4.000e+00, 2.000e+00, 1.000e+00, ..., 4.000e+00, 2.000e+00,
#         1.000e+00]])

# %%
for i in range(0,720):
    for j in range(0,720):
        if(arr[i][j])>255:
            arr[i][j]=0

# %%
arr
# Out:
# array([[0., 0., 0., ..., 4., 2., 1.],
#        [4., 2., 1., ..., 4., 2., 1.],
#        [4., 2., 1., ..., 4., 2., 1.],
#        ...,
#        [4., 2., 1., ..., 4., 2., 1.],
#        [4., 2., 1., ..., 4., 2., 1.],
#        [4., 2., 1., ..., 4., 2., 1.]])

# %%
plt.imshow(arr)
